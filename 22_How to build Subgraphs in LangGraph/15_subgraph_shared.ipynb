# %%
from typing_extensions import TypedDict
from langgraph.graph import StateGraph, START, END
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
class ParentState(TypedDict):

    question: str
    answer_eng: str
    answer_hin: str

# %%
parent_llm = ChatGoogleGenerativeAI(
    model="gemini-3.5-flash-lite",
    temperature=0.2,
)

subgraph_llm = ChatGoogleGenerativeAI(
    model="gemini-3.5-flash-lite",
    temperature=0.2,
)

# %%
def translate_text(state: ParentState):

    prompt = f"""
Translate the following text to Hindi.
Keep it natural and clear. Do not add extra content.

Text:
{state["answer_eng"]}
""".strip()
    
    translated_text = subgraph_llm.invoke(prompt).content

    return {'answer_hin': translated_text}

# %%
subgraph_builder = StateGraph(ParentState)

subgraph_builder.add_node('translate_text', translate_text)

subgraph_builder.add_edge(START, 'translate_text')
subgraph_builder.add_edge('translate_text', END)

subgraph = subgraph_builder.compile()

# %%
def generate_answer(state: ParentState):

    answer = parent_llm.invoke(f"You are a helpful assistant. Answer clearly.\n\nQuestion: {state['question']}").content
    return {'answer_eng': answer}

# %%
parent_builder = StateGraph(ParentState)

parent_builder.add_node("answer", generate_answer)
parent_builder.add_node("translate", subgraph)

parent_builder.add_edge(START, 'answer')
parent_builder.add_edge('answer', 'translate')
parent_builder.add_edge('translate', END)

# %%
graph = parent_builder.compile()

graph

# %%
graph.invoke({'question': 'What is quantum physics'})
# Out:
# c:\Users\kumar\OneDrive\Desktop\Resume\Langraph\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:3908: UserWarning: Model 'gemini-3.5-flash-lite' uses fixed sampling defaults; the sampling parameter(s) temperature will be ignored.
#   request = self._build_request_config(
# Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# c:\Users\kumar\OneDrive\Desktop\Resume\Langraph\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:3908: UserWarning: Model 'gemini-3.5-flash-lite' uses fixed sampling defaults; the sampling parameter(s) temperature will be ignored.
#   request = self._build_request_config(
# {'question': 'What is quantum physics',
#  'answer_eng': [{'type': 'text',
#    'text': '**Quantum physics** (also known as quantum mechanics) is the branch of science that studies the behavior of matter and energy at the most microscopic levels—specifically at the scale of atoms and subatomic particles (like electrons, protons, and photons).\n\nTo understand it, it helps to contrast it with **classical physics** (the physics of everyday life, like gravity and motion discovered by Isaac Newton). While classical physics explains how large things work (like falling apples, speeding cars, and orbiting planets), quantum physics explains how the universe works at a scale so small that normal rules no longer apply.\n\nHere are the core concepts that make quantum physics so strange and fascinating:\n\n### 1. Wave-Particle Duality\nAt the quantum level, tiny particles like electrons and light (photons) behave both as **particles** (solid little billiard balls) and as **waves** (ripples on water). Depending on how you measure them, they can act like one or the other.\n\n### 2. Quantization\nThe word "quantum" comes from "quantity." In the quantum world, certain properties—like energy, light, and angular momentum—come in specific, indivisible amounts called *quanta*. Imagine walking up a ramp (classical physics, where you can stand at any height) versus walking up a staircase (quantum physics, where you can only stand on specific steps). \n\n### 3. Superposition\nIn the quantum world, particles can exist in multiple states or places at the same time until they are observed or measured. This is often illustrated by the famous thought experiment **Schrödinger’s Cat**, which imagines a cat in a box that is simultaneously both alive and dead until someone opens the box to check.\n\n### 4. Quantum Entanglement\nWhen two particles become "entangled," their properties become linked. If you measure the state of one particle, the other particle instantly adopts a corresponding state, no matter how far apart they are—even if they are on opposite sides of the universe. Albert Einstein famously called this "spooky action at a distance."\n\n### 5. The Uncertainty Principle\nFormulated by Werner Heisenberg, this principle states that you cannot simultaneously know both the precise position and the precise momentum (speed and direction) of a particle. The more accurately you try to measure one, the less accurately you can know the other. It is a fundamental limit of nature, not a limitation of our instruments.\n\n---\n\n### Why does it matter?\nWhile quantum physics sounds like science fiction, it is responsible for much of our modern technology. Understanding the quantum realm has allowed us to invent:\n*   **Lasers**\n*   **Transistors** (the building blocks of all computer microchips and smartphones)\n*   **MRI scanners** in medicine\n*   **Quantum computers**, which promise to solve complex problems far faster than today\'s supercomputers.',
#    'extras': {'signature': 'El4KXAERTTIP5UZcWh3MhOIuaF0+DZmtqjoSQ8VlNEhGpuutyu2A4e60rfwCjHqyv/rKzfi34zKd1SCKlI7hS6Dw3CQnWeMs3Jt7HrdbF4af5dvxqgtBZ4QINaOYFYT7'}}],
#  'answer_hin': [{'type': 'text',
#    'text': '**क्वांटम भौतिकी** (जिसे क्वांटम मैकेनिक्स भी कहा जाता है) विज्ञान की वह शाखा है जो बहुत सूक्ष्म स्तर पर—विशेष रूप से परमाणुओं और उप-परमाणु कणों (जैसे इलेक्ट्रॉनों, प्रोटॉनों और फोटॉनों) के पैमाने पर—पदार्थ और ऊर्जा के व्यवहार का अध्ययन करती है।\n\nइसे समझने के लिए, इसकी तुलना **क्लासिकी भौतिकी** (रोजमर्रा की जिंदगी की भौतिकी, जैसे आइजैक न्यूटन द्वारा खोजी गई गुरुत्वाकर्षण और गति) से करना मददगार होता है। जहाँ क्लासिकी भौतिकी यह बताती है कि बड़ी चीजें कैसे काम करती हैं (जैसे गिरते हुए सेब, तेज रफ्तार कारें और परिक्रमा करते ग्रह), वहीं क्वांटम भौतिकी यह बताती है कि ब्रह्मांड ऐसे पैमाने पर कैसे काम करता है जो इतना छोटा है कि सामान्य नियम वहाँ लागू नहीं होते हैं।\n\nयहाँ वे मुख्य अवधारणाएँ दी गई हैं जो क्वांटम भौतिकी को इतना अजीब और आकर्षक बनाती हैं:\n\n### 1. तरंग-कण द्वैत (Wave-Particle Duality)\nक्वांटम स्तर पर, इलेक्ट्रॉन और प्रकाश (फोटॉन) जैसे छोटे कण **कणों** (ठोस छोटी बिलियर्ड गेंदों) और **तरंगों** (पानी की लहरों) दोनों की तरह व्यवहार करते हैं। आप जिस तरह से उनका माप लेते हैं, उसके आधार पर वे दोनों में से किसी एक की तरह काम कर सकते हैं।\n\n### 2. क्वांटीकरण (Quantization)\n"क्वांटम" शब्द "मात्रा" (quantity) से आया है। क्वांटम दुनिया में, कुछ गुण—जैसे ऊर्जा, प्रकाश और कोणीय गति—विशिष्ट, अविभाज्य मात्राओं में होते हैं जिन्हें *क्वांटा* कहा जाता है। रैंप पर चलना (क्लासिकी भौतिकी, जहाँ आप किसी भी ऊंचाई पर खड़े हो सकते हैं) बनाम सीढ़ियों पर चलना (क्वांटम भौतिकी, जहाँ आप केवल विशिष्ट सीढ़ियों पर ही खड़े हो सकते हैं) की कल्पना करें।\n\n### 3. सुपरपोजिशन (Superposition)\nक्वांटम दुनिया में, कण अवलोकन या माप किए जाने तक एक ही समय में कई अवस्थाओं या स्थानों में मौजूद हो सकते हैं। इसे अक्सर प्रसिद्ध विचार प्रयोग **श्रोडिंगर की बिल्ली (Schrödinger’s Cat)** द्वारा समझाया जाता है, जिसमें एक डिब्बे में एक बिल्ली की कल्पना की जाती है जो तब तक एक ही समय में जीवित और मृत दोनों होती है जब तक कोई यह देखने के लिए डिब्बा नहीं खोलता।\n\n### 4. क्वांटम उलझाव (Quantum Entanglement)\nजब दो कण "उलझ" जाते हैं, तो उनके गुण आपस में जुड़ जाते हैं। यदि आप एक कण की अवस्था को मापते हैं, तो दूसरा कण तुरंत एक संबंधित अवस्था को अपना लेता है, चाहे वे कितनी भी दूर हों—भले ही वे ब्रह्मांड के विपरीत छोर पर हों। अल्बर्ट आइंस्टीन ने इसे प्रसिद्ध रूप से "दूरी पर डरावना असर" (spooky action at a distance) कहा था।\n\n### 5. अनिश्चितता का सिद्धांत (The Uncertainty Principle)\nवर्नर हाइजेनबर्ग द्वारा प्रतिपादित, यह सिद्धांत कहता है कि आप एक साथ किसी कण की सटीक स्थिति और उसका सटीक संवेग (गति और दिशा) दोनों नहीं जान सकते। आप जिस एक चीज़ को जितनी अधिक सटीकता से मापने की कोशिश करेंगे, दूसरी चीज़ के बारे में उतनी ही कम सटीकता से जान पाएंगे। यह प्रकृति की एक बुनियादी सीमा है, हमारे उपकरणों की कोई सीमा नहीं है।\n\n---\n\n### यह क्यों महत्वपूर्ण है?\nभले ही क्वांटम भौतिकी विज्ञान कथा (साइंस फिक्शन) जैसी लगती है, लेकिन यह हमारी आधुनिक तकनीक के एक बड़े हिस्से के लिए जिम्मेदार है। क्वांटम जगत को समझने से हमें ये आविष्कार करने में मदद मिली है:\n* **लेज़र**\n* **ट्रांजिस्टर** (सभी कंप्यूटर माइक्रोचिप और स्मार्टफ़ोन के निर्माण खंड)\n* चिकित्सा में **MRI स्कैनर**\n* **क्वांटम कंप्यूटर**, जो आज के सुपरकंप्यूटरों की तुलना में कहीं अधिक तेजी से जटिल समस्याओं को हल करने का वादा करते हैं।',
#    'extras': {'signature': 'El4KXAERTTIPDns1b/IfAt7rQQyFEmm5LwrUCPefOlcgU5z6tI00pbv6upNDKWEtMARzkAxw1XOSc2qI+o4DNbtYi3gKO00JC7dOTgFLVKaIlVTva4JnWlYi3DeAyntt'}}]}
