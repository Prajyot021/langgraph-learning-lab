# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langgraph.graph import StateGraph, START, END
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatGoogleGenerativeAI(
    model="gemini-3.5-flash-lite",
    temperature=0.2,
)

# %%
# create a state

class LLMState(TypedDict):

    question: str
    answer: str

# %%
def llm_qa(state: LLMState) -> LLMState:

    # extract the question from state
    question = state['question']

    # form a prompt
    prompt = f'Answer the following question {question}'

    # ask that question to the LLM
    answer = model.invoke(prompt).content

    # update the answer in the state
    state['answer'] = answer

    return state

# %%
# create our graph

graph = StateGraph(LLMState)

# add nodes
graph.add_node('llm_qa', llm_qa)

# add edges
graph.add_edge(START, 'llm_qa')
graph.add_edge('llm_qa', END)

# compile
workflow = graph.compile()

# %%
# execute

intial_state = {'question': 'How far is moon from the earth?'}

final_state = workflow.invoke(intial_state)

print(final_state['answer'])
# Out:
# c:\Users\kumar\OneDrive\Desktop\Resume\Langraph\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:3908: UserWarning: Model 'gemini-3.5-flash-lite' uses fixed sampling defaults; the sampling parameter(s) temperature will be ignored.
#   request = self._build_request_config(
# [{'type': 'text', 'text': 'The average distance from the Earth to the Moon is about **384,400 kilometers** (or about **238,855 miles**). \n\nBecause the Moon travels in an elliptical (oval-shaped) orbit rather than a perfect circle, this distance changes constantly:\n* **Perigee (Closest point):** About 363,300 km (225,700 miles)\n* **Apogee (Farthest point):** About 405,500 km (251,980 miles) \n\nTo put that distance into perspective, you could fit all the planets in our solar system side-by-side in the space between the Earth and the Moon!', 'extras': {'signature': 'El4KXAERTTIPytMxnrHV7T9qvvpTdXfTlYLfMk31eYh0enG172NeA/1R3M0b2G9L3G19tqYR9UdvVNvUUfMqjxIm1lD0eNtUOtqk2mOdGzSSrxy6p/dFMoPfBy/kCidx'}}]

# %%
model.invoke('How far is moon from the earth?').content
# we could have done this in a single step without creating a graph, but this is just to show how to create a simple workflow using langgraph.
# Out:
# c:\Users\kumar\OneDrive\Desktop\Resume\Langraph\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:3908: UserWarning: Model 'gemini-3.5-flash-lite' uses fixed sampling defaults; the sampling parameter(s) temperature will be ignored.
#   request = self._build_request_config(
# [{'type': 'text',
#   'text': 'The average distance from the Earth to the Moon is about **384,400 kilometers** (238,855 miles). \n\nBecause the Moon travels in an elliptical (oval-shaped) orbit rather than a perfect circle, that distance constantly changes:\n\n* **Closest point (Perigee):** About 363,300 km (225,650 miles) away.\n* **Farthest point (Apogee):** About 405,500 km (251,960 miles) away.\n\nTo put that distance into perspective, you could fit all the planets in our solar system side-by-side in the space between the Earth and the Moon!',
#   'extras': {'signature': 'El4KXAERTTIPG5S/ofiHbTCo2M55Y988OQD3QjXC1msfCB24G3w3U5cUp2Q7uVbdPosBDwRJ9OTxgGXACXYLdKnciOxYMR1oZE0SQn5S/yQVQ4Lo9RHXHhUMGi7QhVz/'}}]
